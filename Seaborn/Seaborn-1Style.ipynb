# %%
import seaborn as sns
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def sinplot(flip=1):
    x = np.linspace(0,14,100)
    for i in range(1,7):
        plt.plot(x,np.sin(x+i *.5)*(7-i)*flip)

sinplot(5)

# %%
sns.set()
sinplot()

# %%
sns.set_style('whitegrid')
data = np.random.normal(size=(20,6) )+ np.arange(6)/2
sns.boxenplot(data=data)

# %%
sns.set()
sinplot()

# %%
sns.set_style('whitegrid')
sns.boxplot(data = data, palette='deep')
sns.despine(left = True,right = True)

# %%
with sns.axes_style('darkgrid'):
    plt.subplot(211)
    sinplot()
plt.subplot(212)
sinplot(-1)

# %%
sns.set_style("whitegrid")
data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
data
#sns.boxplot(data=data);
# Out:
# array([[-2.15769136, -0.09019052,  1.1282785 ,  2.02391726,  2.70453166,
#          3.20908328],
#        [ 0.37526656,  0.29622525, -0.72456349,  1.8919968 ,  1.54134883,
#          1.79110934],
#        [ 0.64726098,  0.39522983,  1.53120157,  0.62094027,  1.49010582,
#          2.00152147],
#        [ 0.21310096, -0.02697878,  1.92411387,  2.75913436,  2.979117  ,
#          3.2799118 ],
#        [-1.25891923,  1.98653493,  0.75104198,  2.89958743,  2.80222277,
#          0.79894889],
#        [-1.09981381,  0.02316083,  0.40887537,  0.83108961,  1.51487263,
#          2.41838602],
#        [-1.46296423,  0.61223246, -0.01231357,  0.12352759,  2.22369297,
#          1.3173536 ],
#        [ 0.64187933, -1.18662207,  0.56578158,  0.65584786, -0.68672602,
#          1.22630066],
#        [ 1.7123809 ,  0.20895642,  3.12601341,  1.96967266, -0.75929207,
#          1.95142211],
#        [-0.63425449, -0.1523622 , -1.55460851,  0.87040462,  2.33035536,
#          2.52198898],
#        [-1.22005568, -0.27749937,  1.89778028, -0.81623735,  1.65055804,
#          0.46941818],
#        [ 0.76603026,  1.60333632,  0.04062902,  2.93847128,  1.70865316,
#          2.79072449],
#        [ 0.64658301, -0.34797704,  1.7081872 , -0.15868284,  0.94461393,
#          3.14282387],
#        [ 1.87704304, -1.3539531 ,  0.35833364,  0.35183739,  1.42431116,
#          2.05943755],
#        [-1.23571784,  1.59580634,  3.05143977,  3.63125364,  1.5613154 ,
#          2.5394782 ],
#        [-0.0720195 , -0.99585152,  1.84150624,  0.66607722,  0.5687055 ,
#          1.54182427],
#        [-2.20423382, -0.22228307,  1.61801383,  1.17746787,  2.06516176,
#          2.8243592 ],
#        [ 0.63600556,  0.39063194,  1.80078014,  1.45284494,  1.59237857,
#          3.03000489],
#        [ 0.19374256, -0.51069086,  1.54267964, -0.19690633,  2.97147079,
#          2.84761085],
#        [-0.523329  , -0.71872092,  1.3938514 ,  1.61985993,  3.24535694,
#          2.14832555]])

# %%
sns.boxplot(data=data)
