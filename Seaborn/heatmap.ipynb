# %%
import numpy as np
import pandas as pd
from scipy import stats,integrate
import matplotlib.pyplot as  plt
import seaborn as sns
import matplotlib as mpl
np.random.seed(0)
sns.set()

# %%
uniform_data = np.random.rand(100,100)
heatmap = sns.heatmap(uniform_data,center=0.5)
#uniform_data
